# %%
# %sql
create or replace table workspace.default.cdctable (
  userId int,
  name string,
  city string,
  date_col date
)

# %%
# %sql
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(1,'Alice','New York','2023-01-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(2,'Bob','Chicago','2023-02-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(3,'Charlie','San Francisco','2023-03-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(4,'David','Los Angeles','2023-04-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(5,'Eva','Seattle','2023-05-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(6,'Frank','Austin','2023-06-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(7,'Grace','Boston','2023-07-01');
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(8,'Hank','Miami','2023-08-01');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from cdctable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from target_scd1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>name</th><th>city</th></tr></thead><tbody><tr><td>2</td><td>Bob</td><td>Chicago</td></tr><tr><td>3</td><td>Charlie</td><td>San Francisco</td></tr><tr><td>4</td><td>David</td><td>Los Angeles</td></tr><tr><td>5</td><td>Eva</td><td>Seattle</td></tr><tr><td>6</td><td>Frank</td><td>Austin</td></tr><tr><td>7</td><td>Grace</td><td>Boston</td></tr><tr><td>8</td><td>Hank</td><td>Miami</td></tr><tr><td>1</td><td>Chinna</td><td>Hyderabad</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.default.cdctable
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
INSERT INTO workspace.default.cdctable (userId,name,city,date_col) VALUES(1,'Ajay','Chennai','2023-11-01');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
create or replace table workspace.default.cdctable2 (
  userId int,
  name string,
  city string,
  sequence int
)

# %%
# %sql
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(1,'Alice','New York',1);
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(2,'Bob','Chicago',2);
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(3,'Charlie','San Francisco',3);
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(4,'David','Los Angeles',4);
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(5,'Eva','Seattle',5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.default.cdctable2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>name</th><th>city</th><th>sequence</th></tr></thead><tbody><tr><td>3</td><td>Charlie</td><td>San Francisco</td><td>3</td></tr><tr><td>4</td><td>David</td><td>Los Angeles</td><td>4</td></tr><tr><td>5</td><td>Praveen</td><td>Chennai</td><td>8</td></tr><tr><td>1</td><td>Alice</td><td>New York</td><td>1</td></tr><tr><td>5</td><td>Eva</td><td>Seattle</td><td>5</td></tr><tr><td>2</td><td>Bob</td><td>Chicago</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select * from workspace.default.target_scd2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>userId</th><th>name</th><th>city</th><th>__START_AT</th><th>__END_AT</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>New York</td><td>1</td><td>null</td></tr><tr><td>2</td><td>Bob</td><td>Chicago</td><td>2</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>San Francisco</td><td>3</td><td>null</td></tr><tr><td>4</td><td>David</td><td>Los Angeles</td><td>4</td><td>null</td></tr><tr><td>5</td><td>Praveen</td><td>Chennai</td><td>8</td><td>null</td></tr><tr><td>5</td><td>Eva</td><td>Seattle</td><td>5</td><td>8</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO workspace.default.cdctable2 (userId,name,city,sequence) VALUES(5,'Praveen','Chennai',8);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>
